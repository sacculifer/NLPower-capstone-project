# %% [markdown]
# ## Loading Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import ujson as json


import string
import re

from textatistic import Textatistic

import spacy

import warnings

warnings.filterwarnings('ignore')

RSEED = 42

# %% [markdown]
# ## Data cleaning

# %%
nlp = spacy.load('en_core_web_lg')
stopwords = spacy.lang.en.STOP_WORDS

# %%
def preprocess(text):
    doc = nlp(text, disable=['ner', 'parser'])
    lemmas = [token.lemma_ for token in doc]
    a_lemmas = [lemma for lemma in lemmas 
              if lemma.isalpha() and lemma not in stopwords]
    return a_lemmas

# %%
def remove_entities(text):
    doc = nlp(text)
    return(" ".join([ent.text for ent in doc if not ent.ent_type_]))

# %%
def remove_html(text):
    html = re.compile(r'<.*?>|&([a-z0-9]+|#[0-9]{1,6}|#x[0-9a-f]{1,6});')
    return html.sub(r'', text)

# %%
def remove_ebola(text):
    words = re.compile('(\s*)ebola(\s*)')
    return words.sub(r" ", text)

# %%
def remove_mers(text):
    words = re.compile('(\s*)mers(\s*)')
    return words.sub(r" ", text)

# %%
def remove_helicopter(text):
    words = re.compile('(\s*)helicopter(\s*)')
    return words.sub(r" ", text)

# %%
def remove_train(text):
    words = re.compile('(\s*)train(\s*)')
    return words.sub(r" ", text)

# %%
import os
path = "../data_dimbat/incident-tweets/"
files = os.listdir(path)
df_list = list()
for file in files:
    records = map(json.loads, open(os.path.join(path, file), encoding="utf8"))
    df = pd.DataFrame.from_records(records)
    df["text_clean"] = df["text"].apply(lambda x: remove_html(x))
    df['lemmas'] = df['text_clean'].apply(preprocess)   
    df["text_lemma"] = [' '.join(map(str, x)) for x in df["lemmas"]]
    df['text_lemma'] = df['text_lemma'].apply(remove_entities)
    df_list.append(df)

# %%
def findWholeWord(w):
    return re.compile(r'\b({0})\b'.format(w), flags=re.IGNORECASE).search

# %%
for i in range(len(files)):
    if findWholeWord('ebola')(files[i]):
        df_list[i]['text_lemma'] = df_list[i]['text_lemma'].apply(remove_ebola)
    elif findWholeWord('mers')(files[i]):
        df_list[i]['text_lemma'] = df_list[i]['text_lemma'].apply(remove_mers)
    elif findWholeWord('helicopter')(files[i]):
        df_list[i]['text_lemma'] = df_list[i]['text_lemma'].apply(remove_helicopter)
    elif findWholeWord('train')(files[i]):
        df_list[i]['text_lemma'] = df_list[i]['text_lemma'].apply(remove_train)

# %%
df_sum = df_list[0]

# %%
for i in range(1, len(df_list)):
   df_sum = df_sum.append(df_list[i], ignore_index=True)

# %%
df_sum.sample(20)
# Out:
#                           id  \
# 93001     690722254292979712
# 68827   '511452413757108224'
# 97056   '347945641789497344'
# 10701   '497087009736126464'
# 66693     442165443109720064
# 90964     844247183230668800
# 143306  '262593874428571649'
# 80127     788503477899169792
# 121614    907943262174040064
# 15046   '451189143637610496'
# 57117     177098419612037120
# 88690     591902761412743168
# 56477     598797567250444288
# 22728   '575771100216365056'
# 107858    709821541048000512
# 28405     910047365482004481
# 160412    911664846420234240
# 31514     766063882498674688
# 83033     207476829987155968
# 98269   '350106170977042433'
#
#                                                      text  relevance  \
# 93001   district 'aware, outraged' by racist photo all...          0
# 68827   =net news today malta ship sinks <NUMBER> dead...          1
# 97056   looks like there's a lot of power outages. one...          1
# 10701   i've been telling peole for <NUMBER> years tha...          1
# 66693   <USER> hi sun extra.quick q-y has the ind elec...          0
# 90964   <USER> @nicolasturgeon hear that? that's the s...          0
# 143306  i wish i would've been the one to create the <...          1
# 80127   been dancing around to the <HASHTAG> tejanoque...          0
# 121614  <HASHTAG> foxalgeria 'the nation' compares cli...          1
# 15046     my prayers goes out to u <HASHTAG> prayforchile          1
# 57117   <USER> <HASHTAG> np jayz and biggie " i love t...          0
# 88690   don't expect much from the government buy wate...          1
# 56477   <USER> idk something about the interior just d...          0
# 22728   <USER> @pamnparsons not sure if question is fo...          1
# 107858  esses tweets antigos do neymar são ótimos ne d...          0
# 28405   hurricane irma’s impact on the bvi and what no...          1
# 160412  popocatã©petl volcano, <NUMBER> km southeast o...          1
# 31514   citizens fund <HASHTAG> socialsecurity we pay ...          0
# 83033   another one? rt <USER> italy rocked by <NUMBER...          1
# 98269   are you on your way to help with the <HASHTAG>...          1
#
#                                                text_clean  \
# 93001   district 'aware, outraged' by racist photo all...
# 68827   =net news today malta ship sinks  dead=logic  ...
# 97056   looks like there's a lot of power outages. one...
# 10701   i've been telling peole for  years that  afric...
# 66693    hi sun extra.quick q-y has the ind elect medi...
# 90964    @nicolasturgeon hear that? that's the silent ...
# 143306  i wish i would've been the one to create the  ...
# 80127   been dancing around to the  tejanoqueen all ni...
# 121614   foxalgeria 'the nation' compares climate chan...
# 15046              my prayers goes out to u  prayforchile
# 57117     np jayz and biggie " i love the doe"” more t...
# 88690   don't expect much from the government buy wate...
# 56477    idk something about the interior just doesn't...
# 22728    @pamnparsons not sure if question is for me o...
# 107858  esses tweets antigos do neymar são ótimos ne d...
# 28405   hurricane irma’s impact on the bvi and what no...
# 160412  popocatã©petl volcano,  km southeast of mexico...
# 31514   citizens fund  socialsecurity we pay into it f...
# 83033   another one? rt  italy rocked by  earthquake; ...
# 98269   are you on your way to help with the  yycflood...
#
#                                                    lemmas  \
# 93001   [district, aware, outraged, racist, photo, all...
# 68827   [net, news, today, malta, ship, sink, dead, lo...
# 97056   [look, like, lot, power, outage, inglewood, ar...
# 10701   [I, tell, peole, year, africans, evolve, ebola...
# 66693   [hi, sun, q, y, ind, elect, medium, carry, sto...
# 90964                [hear, silent, majority, bide, time]
# 143306      [I, wish, I, create, sandy, novelty, account]
# 80127   [dance, tejanoqueen, night, emotion, right, lo...
# 121614  [foxalgeria, nation, compare, climate, change,...
# 15046                           [prayer, u, prayforchile]
# 57117              [np, jayz, biggie, I, love, doe, know]
# 88690   [expect, government, buy, water, purifier, cle...
# 56477   [idk, interior, cut, I, maybe, I, test, drive,...
# 22728               [sure, question, I, pam, big, yes, I]
# 107858  [esse, tweet, antigo, neymar, são, ótimos, ne,...
# 28405        [hurricane, irma, impact, bvi, need, happen]
# 160412  [popocatã, petl, volcano, km, southeast, mexic...
# 31514   [citizen, fund, socialsecurity, pay, security,...
# 83033                 [rt, italy, rock, earthquake, dead]
# 98269   [way, help, yycflood, cleanup, stop, send, doz...
#
#                                                text_lemma
# 93001   district aware outraged racist photo allegedly...
# 68827   net news ship sink dead logic webdic nd c star...
# 97056   look like lot power outage inglewood area blac...
# 10701   I tell peole year evolve dyingindessert starva...
# 66693   hi sun q y ind elect medium carry story tata t...
# 90964                      hear silent majority bide time
# 143306              I wish I create sandy novelty account
# 80127                            dance emotion right love
# 121614  foxalgeria nation compare climate change denie...
# 15046                               prayer u prayforchile
# 57117                           np biggie I love doe know
# 88690   expect government buy water purifier clean sur...
# 56477     idk interior cut I maybe I test drive different
# 22728                       sure question I pam big yes I
# 107858                                    esse tweet vote
# 28405                    hurricane impact bvi need happen
# 160412           km southeast erupt hour mexicoearthquake
# 31514                           security rob fund wiunion
# 83033                                                dead
# 98269   way help yycflood cleanup stop send doughnut c...

# %%
df_sum.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 163718 entries, 0 to 163717
# Data columns (total 6 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   id          160958 non-null  object
#  1   text        163718 non-null  object
#  2   relevance   163718 non-null  int64
#  3   text_clean  163718 non-null  object
#  4   lemmas      163718 non-null  object
#  5   text_lemma  163718 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 7.5+ MB

# %%
df_sum.to_pickle("../data/preprocess_train_dimbat_1.pkl")

# %%
df_new = pd.read_pickle("../data/preprocess_train_dimbat_1.pkl")

# %%
df_new.sample(30)
# Out:
#                           id  \
# 60037     943302861240356864
# 83114     301914160558641152
# 96207     386188532437352448
# 58335     693253611577577472
# 1064      766063840480137216
# 160122    910650995415195648
# 89702     591912766279012353
# 140646    869988473419309059
# 118098    128515670081146880
# 99630   '350234461981519874'
# 110822    399284931425501184
# 155759  '503644709525274624'
# 35164   '324039852075143168'
# 159215    939333300883111936
# 1565    '460398064923344896'
# 143120  '263084361342124032'
# 133369  '498508270890258432'
# 159541    413865776773218304
# 137119    624639694857478144
# 68213   '511436152503406593'
# 69117     748705647248699392
# 66411     392171471520284672
# 2371    '460561456644501504'
# 64432     910541034387644416
# 86120     592593377843159040
# 31432     795695265344815104
# 147544  '262603156586893314'
# 89361     591903258140086272
# 156942   1033171717454213120
# 139105    396326609118322688
#
#                                                      text  relevance  \
# 60037   rt &amp; follow <USER> for a chance to win a <...          0
# 83114               <USER> are you stalking my twitter? 😳          0
# 96207   <NUMBER> t one to fix deal <NUMBER> come out o...          0
# 58335   no need to worry about harvard in the ivy race...          0
# 1064    <NUMBER> marleen still can't even take a compl...          0
# 160122  yesterday, mexico was hit by a powerful earthq...          1
# 89702   <NUMBER> dead so far, nepalearthquake. many in...          1
# 140646  misery in the <HASHTAG> rohingya <HASHTAG> ref...          1
# 118098     it's so brisk out  <REPEAT> sheesh  <REPEAT>          0
# 99630   fire department is looking at disconnecting so...          1
# 110822        google crisis map <HASHTAG> yolandaph <URL>          1
# 155759  â†’ usa <URL> â†’ northern california earthqua...          1
# 35164   i can't sleep now  <REPEAT> my heart and pray...          1
# 159215  a pregnant inmate had a miscarriage days after...          0
# 1565    communicable disease threats report week <NUMB...          1
# 143120  parts of brooklyn and manhattan are flooding a...          1
# 133369  <NUMBER> may <NUMBER> he first day and night c...          1
# 159541  every bodies finished w/ exams &amp;&amp; here...          0
# 137119                happy birthday gary g🚬 <USER> <URL>          0
# 68213   <USER> oops! <USER> photo: airport in los cabo...          1
# 69117                       sorry not sorry <SMILE> <URL>          0
# 66411   piso mo, hospital ko program launched to rebui...          1
# 2371    third case of mers confirmed in the u.s. <URL>...          1
# 64432   <HASHTAG> happychenday <HASHTAG> happychenday ...          0
# 86120   top story: help children in nepal: donate for ...          1
# 31432        <USER> wonder how many t-shirts he's ruined?          0
# 147544  <USER> i'm a independent sassy black hurricane...          1
# 89361   *in real time * <HASHTAG> nepalearthquake indi...          1
# 156942  i made something <SMILE> <HASHTAG> fentyxkai <...          0
# 139105  update: shooting has ended, <NUMBER> d suspect...          1
#
#                                                text_clean  \
# 60037   rt  follow  for a chance to win a  exclusive t...
# 83114                      are you stalking my twitter? 😳
# 96207    t one to fix deal  come out on bail  d to foo...
# 58335   no need to worry about harvard in the ivy race...
# 1064          marleen still can't even take a compliment
# 160122  yesterday, mexico was hit by a powerful earthq...
# 89702    dead so far, nepalearthquake. many injured. o...
# 140646  misery in the  rohingya  refugee camps after c...
# 118098                     it's so brisk out   sheesh
# 99630   fire department is looking at disconnecting so...
# 110822                      google crisis map  yolandaph
# 155759  â†’ usa  â†’ northern california earthquake is...
# 35164   i can't sleep now   my heart and prayer are w...
# 159215  a pregnant inmate had a miscarriage days after...
# 1565    communicable disease threats report week  with...
# 143120  parts of brooklyn and manhattan are flooding a...
# 133369   may  he first day and night cricket match of ...
# 159541  every bodies finished w/ exams  here i sit in ...
# 137119                           happy birthday gary g🚬
# 68213    oops!  photo: airport in los cabos, severely ...
# 69117                                   sorry not sorry
# 66411   piso mo, hospital ko program launched to rebui...
# 2371    third case of mers confirmed in the u.s.  the ...
# 64432    happychenday  happychenday  الطف مخلوق على وج...
# 86120   top story: help children in nepal: donate for ...
# 31432               wonder how many t-shirts he's ruined?
# 147544   i'm a independent sassy black hurricane who d...
# 89361   *in real time *  nepalearthquake india : so sa...
# 156942                      i made something   fentyxkai
# 139105  update: shooting has ended,  d suspect taken i...
#
#                                                    lemmas  \
# 60037   [rt, follow, chance, win, exclusive, joker, bi...
# 83114                                    [stalk, twitter]
# 96207   [t, fix, deal, come, bail, d, fool, seemandhra...
# 58335           [need, worry, harvard, ivy, race, season]
# 1064                                [marleen, compliment]
# 160122     [yesterday, mexico, hit, powerful, earthquake]
# 89702   [dead, far, nepalearthquake, injure, bad, time...
# 140646  [misery, rohingya, refugee, camp, cyclone, mor...
# 118098                                    [brisk, sheesh]
# 99630   [fire, department, look, disconnect, car, end,...
# 110822                   [google, crisis, map, yolandaph]
# 155759  [usa, northern, california, earthquake, strong...
# 35164    [I, sleep, heart, prayer, boston, prayforboston]
# 159215  [pregnant, inmate, miscarriage, day, tase, rec...
# 1565    [communicable, disease, threat, report, week, ...
# 143120  [brooklyn, manhattan, flood, power, outage, I,...
# 133369  [day, night, cricket, match, india, play, floo...
# 159541              [body, finish, exam, I, sit, library]
# 137119                         [happy, birthday, gary, g]
# 68213   [oop, photo, airport, los, cabo, severely, dam...
# 69117                                      [sorry, sorry]
# 66411   [piso, mo, hospital, ko, program, launch, rebu...
# 2371    [case, mer, confirm, center, disease, control,...
# 64432   [happychenday, happychenday, الطف, مخلوق, على,...
# 86120   [story, help, child, nepal, donate, earthquake...
# 31432                            [wonder, t, shirt, ruin]
# 147544  [I, independent, sassy, black, hurricane, need...
# 89361   [real, time, nepalearthquake, india, sad, bang...
# 156942                                     [I, fentyxkai]
# 139105  [update, shooting, end, d, suspect, custody, d...
#
#                                                text_lemma
# 60037   rt follow chance win exclusive joker bit pop c...
# 83114                                       stalk twitter
# 96207   t fix deal come bail d fool seemandhra people ...
# 58335                         need worry harvard ivy race
# 1064                                           compliment
# 160122                            hit powerful earthquake
# 89702     dead far nepalearthquake injure bad time nation
# 140646  misery rohingya refugee camp cyclone mora wall...
# 118098                                       brisk sheesh
# 99630   fire department look disconnect car end yycflo...
# 110822                        google crisis map yolandaph
# 155759         usa northern earthquake strong year strong
# 35164                  I sleep heart prayer prayforboston
# 159215  pregnant inmate miscarriage day tase recent re...
# 1565      communicable disease threat report update ebola
# 143120                          flood power outage I good
# 133369  day night cricket match play flood light groun...
# 159541                     body finish exam I sit library
# 137119                              happy birthday gary g
# 68213    oop photo airport severely damage hurricaneodile
# 69117                                         sorry sorry
# 66411   program launch rebuild ccmc donation deposit a...
# 2371    case confirm center disease control prevention...
# 64432                                               الارض
# 86120   story help child nepal donate earthquake respo...
# 31432                                 wonder t shirt ruin
# 147544  I independent sassy black hurricane need man i...
# 89361                  real time nepalearthquake sad ball
# 156942                                        I fentyxkai
# 139105  update shooting end d suspect custody detail c...
